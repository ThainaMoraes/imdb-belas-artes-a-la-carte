# %%
import functions.Imports as imp
import functions.Imdb_SQLite as SQL
import functions.findMoviesInDataBase as query
import functions.ReadAndWriteFiles as readWriteFile

# %%
# %%time
# !imdb-sqlite

# %%
# SQL.howImdbTablesAreOrganized()

# %%
# %%time
# lista_filmes = query.uptadeTilesList('lista_filmes')
w = query.updateMovieList('lista_filmes')
# Out:
# p1
# p2
# p3
# p4
# p5
# p6
# p7
# p8
# p88
# List of movies updated (added and removed)
# CPU times: user 673 ms, sys: 14.5 ms, total: 687 ms
# Wall time: 8.48 s

# %%
original_title = "OPERAÇÃO WINDSOR | TO CATCH A KING | 115 min | Estados Unidos | 1984| Thriller | Drama |Direção: Clive Donner"
indexs = [i for i in range(0,len(original_title)) if original_title[i] == '|']

# %%
def teste():
    sair =0
    ind=0
    while sair == 0:
        original_title = "OPERAÇÃO WINDSOR | TO CATCH A KING | 115 min | Estados Unidos | 1984| Thriller | Drama |Direção: Clive Donner"
        indexs = [i for i in range(0,len(original_title)) if original_title[i] == '|']

        if original_title[indexs[ind] + 1] != " ":
            index_year_start = indexs[ind] + 1
            index_year_final = indexs[ind] + 5
            print(original_title[index_year_start:index_year_final])

        try:
            int(original_title[index_year_start: index_year_final])
            sair = 1
        except:
            sair =0
            ind = ind + 1
    #             else:
    #                 i = 1
    #                 while original_title[indexs[ind] + i] == " ":
    #                     index_year_start = indexs[ind] + i + 1
    #                     index_year_final = indexs[ind] + i + 5
    #                     i = i + 1
    #             return index_year_start,index_year_final

    #             int(original_title[index_year_start: index_year_final])
teste()
# Out:
# Dire
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [7], in <cell line: 28>()
#      18             ind = ind + 1
#      19     #             else:
#      20     #                 i = 1
#      21     #                 while original_title[indexs[ind] + i] == " ":
#    (...)
#      26
#      27     #             int(original_title[index_year_start: index_year_final])
# ---> 28 teste()
#
# Input In [7], in teste()
#       5 original_title = "OPERAÇÃO WINDSOR | TO CATCH A KING | 115 min | Estados Unidos | 1984| Thriller | Drama |Direção: Clive Donner"
#       6 indexs = [i for i in range(0,len(original_title)) if original_title[i] == '|']
# ----> 8 if original_title[indexs[ind] + 1] != " ":
#       9     index_year_start = indexs[ind] + 1
#      10     index_year_final = indexs[ind] + 5
#
# IndexError: list index out of range

# %%
original_title[index_year_start:index_year_final]
# Out:
# '115 '

# %%
readWriteFile.readFile('lista_filmes')
# Out:
# [{'portuguese_title': 'Espionagem',
#   'original_title': 'OPERAÇÃO WINDSOR',
#   'year': '115 '},
#  {'portuguese_title': 'Mentiras do bem',
#   'original_title': 'WHITE LIES',
#   'year': '1997'},
#  {'portuguese_title': 'Um nome na lista',
#   'original_title': 'FADE TO BLACK',
#   'year': '2006'},
#  {'portuguese_title': 'Os terraços',
#   'original_title': 'ES-STOUH',
#   'year': '2013'},
#  {'portuguese_title': 'Flores partidas',
#   'original_title': 'BROKEN FLOWERS',
#   'year': '2005'},
#  {'portuguese_title': 'Eu sou Cuba',
#   'original_title': 'SOY CUBA',
#   'year': '1964'},
#  {'portuguese_title': 'Duas famílias',
#   'original_title': 'I PREDATORI',
#   'year': '2020'},
#  {'portuguese_title': 'Uma outra mulher',
#   'original_title': 'ICH BIN DIE ANDERE',
#   'year': '2006'},
#  {'portuguese_title': 'Villa-Lobos - uma vida de paixão',
#   'original_title': 'VILLA-LOBOS - UMA VIDA DE PAIXÃO',
#   'year': '2000'},
#  {'portuguese_title': 'Tigre branco',
# ...

# %%
# readWriteFile.saveFile(lista_filmes,"arquivo_com_os_filmes",tipo='df')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 readWriteFile.saveFile(lista_filmes,"arquivo_com_os_filmes",tipo='df')
#
# NameError: name 'lista_filmes' is not defined
